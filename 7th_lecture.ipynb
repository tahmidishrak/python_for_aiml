# %% [markdown]
# # Exception Handling

# %% [markdown]
# ## Exception Handling Keyword

# %% [markdown]
# ### Try Keyword

# %%
a = int(input("Give your number: "))
try:
    print(10/a)
except Exception as err:
    print(f"There is an error as {err}")
else:
    print("Good no occurs have this code")
finally:
    print("i will run what matter")
print("Complete")
# Out:
# Give your number:  0
# There is an error as division by zero
# i will run what matter
# Complete
